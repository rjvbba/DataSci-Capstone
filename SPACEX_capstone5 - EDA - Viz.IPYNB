# %%
# pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
#NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np
# Matplotlib is a plotting library for python and pyplot gives us a MatLab like plotting framework. We will use this in our plotter function to plot data.
import matplotlib.pyplot as plt
#Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics
import seaborn as sns

# %%
import requests
import io

# Define the URL of the CSV file
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_2.csv"

# Fetch the data using requests
response = requests.get(URL)

# Check if the request was successful
if response.status_code == 200:
    # Convert the response content into a BytesIO object and read as CSV
    dataset_part_2_csv = io.BytesIO(response.content)
    df = pd.read_csv(dataset_part_2_csv)

    # Display first 5 rows
    print(df.head(5))
else:
    print("Failed to fetch data:", response.status_code)
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# 0            0  B0003  -80.577366  28.561857      0
# ...

# %%
sns.catplot(y="PayloadMass", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Pay load Mass (kg)",fontsize=20)
plt.show()

# %%
sns.catplot(y="LaunchSite", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("LaunchSite",fontsize=20)
plt.show()

# %%
sns.scatterplot(y="LaunchSite", x="PayloadMass", hue="Class", data=df)
plt.xlabel("PayloadMass",fontsize=20)
plt.ylabel("LaunchSite",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="Orbit", y="Class", data=df, palette="viridis")

# Formatting
plt.xlabel("Orbit", fontsize=14)
plt.ylabel("Success Rate", fontsize=14)
plt.title(f"Success Rate by Orbit", fontsize=16)


plt.show()
# Out:
# C:\Users\renat\AppData\Local\Temp\ipykernel_22364\1968183847.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Orbit", y="Class", data=df, palette="viridis")

# %%
sns.scatterplot(y="FlightNumber", x="Orbit", hue="Class", data=df)
plt.xlabel("Orbit",fontsize=20)
plt.ylabel("FlightNumber",fontsize=20)
plt.show()

# %%
sns.scatterplot(y="Orbit", x="PayloadMass", hue="Class", data=df)
plt.xlabel("PayloadMass",fontsize=20)
plt.ylabel("Orbit",fontsize=20)
plt.show()

# %%
year=[]
def Extract_year():
    for i in df["Date"]:
        year.append(i.split("-")[0])
    return year
Extract_year()
df['Date'] = year
df.head()
# Out:
#    FlightNumber  Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# 0            0  B0003  -80.577366  28.561857      0
# ...

# %%
plt.plot("Date","Class", data=df)
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.title("Simple Line Chart")
plt.show()

# %%
features = df[['FlightNumber', 'PayloadMass', 'Orbit', 'LaunchSite', 'Flights', 'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Serial']]
features
# Out:
#     FlightNumber   PayloadMass Orbit    LaunchSite  Flights  GridFins  Reused  \
# 0              1   6104.959412   LEO  CCAFS SLC 40        1     False   False
# 1              2    525.000000   LEO  CCAFS SLC 40        1     False   False
# 2              3    677.000000   ISS  CCAFS SLC 40        1     False   False
# 3              4    500.000000    PO   VAFB SLC 4E        1     False   False
# 4              5   3170.000000   GTO  CCAFS SLC 40        1     False   False
# ..           ...           ...   ...           ...      ...       ...     ...
# 73            74  15600.000000  VLEO  CCAFS SLC 40        3      True    True
# 72            73   6104.959412    SO    KSC LC 39A        4     False    True
# 88            89  15400.000000  VLEO  CCAFS SLC 40        3      True    True
# 79            80  15400.000000  VLEO  CCAFS SLC 40        5      True    True
# 89            90   3681.000000   MEO  CCAFS SLC 40        1      True   False
#
# ...

# %%
features[["GridFins", "Reused", "Legs"]] = features[["GridFins", "Reused", "Legs"]].astype(int)

# One-hot encode categorical features
dummies = pd.get_dummies(features[['GridFins', 'Reused', 'Legs']])

# Drop original categorical columns
features = features.drop(columns=['GridFins', 'Reused', 'Legs'])

# Concatenate original DataFrame with the new dummy variables
features = pd.concat([features, dummies], axis=1)

# Display the updated DataFrame
print(features)
# Out:
#     FlightNumber   PayloadMass Orbit    LaunchSite  Flights  \
# 0              1   6104.959412   LEO  CCAFS SLC 40        1
# 1              2    525.000000   LEO  CCAFS SLC 40        1
# 2              3    677.000000   ISS  CCAFS SLC 40        1
# 3              4    500.000000    PO   VAFB SLC 4E        1
# 4              5   3170.000000   GTO  CCAFS SLC 40        1
# ..           ...           ...   ...           ...      ...
# 73            74  15600.000000  VLEO  CCAFS SLC 40        3
# 72            73   6104.959412    SO    KSC LC 39A        4
# 88            89  15400.000000  VLEO  CCAFS SLC 40        3
# 79            80  15400.000000  VLEO  CCAFS SLC 40        5
# 89            90   3681.000000   MEO  CCAFS SLC 40        1
#
#                   LandingPad  Block  ReusedCount Serial  GridFins  Reused  \
# 0                        NaN    1.0            0  B0003         0       0
# 1                        NaN    1.0            0  B0005         0       0
# ...

# %%
features[["PayloadMass", "Flights", "Block", "ReusedCount"]] = features[["PayloadMass", "Flights", "Block", "ReusedCount"]].astype("float64")

# %%
features
# Out:
#     FlightNumber   PayloadMass Orbit    LaunchSite  Flights  \
# 0              1   6104.959412   LEO  CCAFS SLC 40      1.0
# 1              2    525.000000   LEO  CCAFS SLC 40      1.0
# 2              3    677.000000   ISS  CCAFS SLC 40      1.0
# 3              4    500.000000    PO   VAFB SLC 4E      1.0
# 4              5   3170.000000   GTO  CCAFS SLC 40      1.0
# ..           ...           ...   ...           ...      ...
# 73            74  15600.000000  VLEO  CCAFS SLC 40      3.0
# 72            73   6104.959412    SO    KSC LC 39A      4.0
# 88            89  15400.000000  VLEO  CCAFS SLC 40      3.0
# 79            80  15400.000000  VLEO  CCAFS SLC 40      5.0
# 89            90   3681.000000   MEO  CCAFS SLC 40      1.0
#
#                   LandingPad  Block  ReusedCount Serial  GridFins  Reused  \
# 0                        NaN    1.0          0.0  B0003         0       0
# 1                        NaN    1.0          0.0  B0005         0       0
# ...
